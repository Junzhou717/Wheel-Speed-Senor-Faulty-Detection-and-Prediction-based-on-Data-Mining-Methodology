# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/wss')

# %%
results = pd.DataFrame(df)
results.head()
# Out:
#   accountid  avgload  avgspeed         bssid bssid1 bssid2 bssid3  \
# 0     A3J43      NaN         1  BC765EEC523A
# 1     A3J43      NaN         1  BC765EEC523A
# 2     A3J43      NaN       255  BC765EEC523A
# 3     A3J43      NaN       255  BC765EEC523A
# 4     A3J43      NaN         1  BC765EEC523A
#
#                created_at           eventtime  drivenum  \
# 0 2017-04-24 11:44:20.365 2016-12-12 13:33:12         5
# 1 2017-04-24 11:44:20.365 2016-12-12 13:38:10         9
# 2 2017-04-24 11:44:20.365 2016-12-12 16:31:04        14
# 3 2017-04-24 11:44:20.365 2017-01-29 08:56:22        18
# 4 2017-04-24 11:44:42.082 2016-12-12 14:04:23         4
#
#            ...            p1presspoweroff padwearstat schemavers  servprvder  \
# 0          ...                     6200.0         NaN          3           1
# 1          ...                     6200.0         NaN          3           1
# 2          ...                     7500.0         NaN          3           1
# 3          ...                     4500.0         NaN          3           1
# 4          ...                     5900.0         NaN          3           1
#
#    softgpsloc  totaldist  tripdist  warnlampstat     itappin  \
# 0                    0.0       0.0             1  1888062301
# 1                    0.0       0.0             1  1888062301
# 2                    0.0       0.0             0  1888062301
# 3                    0.0       0.0             0  1888062301
# 4                    0.0       0.0             1  4099311238
#
#                 itapudid
# 0  163540005001DC915C983
# 1  163540005001DC915C983
# 2  163540005001DC915C983
# 3  163540005001DC915C983
# 4  163540006001DC915B4EF
#
# [5 rows x 36 columns]

# %%
pd.set_option('display.max_rows', 50)
results = results[['itapudid', 'max1stdetectwssc', 'max1stdetectwssd', 'max1stdetectwsse', 'max1stdetectwssf', 'eventtime']]
results.fillna(0)
results.to_pickle('../data/wss_n1')

# %%
df_n_nd = results[results.itapudid != '170540055001DC915C90E']
df_n3 = results[results.itapudid == '170540055001DC915C90E']

# %%
df_nc = df_n_nd[['itapudid', 'max1stdetectwssc', 'eventtime']]
df_nc['sensor'] = 'C'
df_nc.columns = ['itapudid', 'speed', 'eventtime', 'sensor']
df_nc.speed.fillna(0, inplace=True)

df_nd = df_n_nd[['itapudid', 'max1stdetectwssd', 'eventtime']]
df_nd['sensor'] = 'D'
df_nd.columns = ['itapudid', 'speed', 'eventtime', 'sensor']
df_nd.speed.fillna(0, inplace=True)

df_ne = df_n_nd[['itapudid', 'max1stdetectwsse', 'eventtime']]
df_ne['sensor'] = 'E'
df_ne.columns = ['itapudid', 'speed', 'eventtime', 'sensor']
df_ne.speed.fillna(0, inplace=True)

df_nf = df_n_nd[['itapudid', 'max1stdetectwssf', 'eventtime']]
df_nf['sensor'] = 'F'
df_nf.columns = ['itapudid', 'speed', 'eventtime', 'sensor']
df_nf.speed.fillna(0, inplace=True)
# Out:
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py:3549: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
frame1 = [df_nc, df_nd]
frame2 = [df_ne, df_nf]
re1 = pd.concat(frame1)
re2 = pd.concat(frame2)

# %%
test1 = re1.sort_values(['eventtime','itapudid'])
test2 = re2.sort_values(['eventtime','itapudid'])

# %%
test1.to_pickle('../data/wss_n_1')  # pickle dataframe
test2.to_pickle('../data/wss_n_2')  # pickle dataframe
