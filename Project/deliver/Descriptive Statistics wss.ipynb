# %%
import pandas as pd
df = pd.read_pickle('../data/wss_n_c1')
df.head(50)
# Out:
#                     itapudid  speed  eventtime sensor
# 7185   163540031001DC924C7B3    0.0 1970-01-01      C
# 7185   163540031001DC924C7B3    0.0 1970-01-01      D
# 6654   163540032001DC9248262    0.0 1970-01-01      E
# 6654   163540032001DC9248262    0.0 1970-01-01      F
# 17071  164320032001DC92C8F02    0.0 1970-01-01      C
# 17071  164320032001DC92C8F02    0.0 1970-01-01      D
# 14882  164320033001DC924D8F0    0.0 1970-01-01      C
# 14882  164320033001DC924D8F0    0.0 1970-01-01      D
# 21759  164750011001DC915CDB2    0.0 1970-01-01      C
# 21759  164750011001DC915CDB2    0.0 1970-01-01      D
# 21768  164750013001DC92C9043    0.0 1970-01-01      C
# 21768  164750013001DC92C9043    0.0 1970-01-01      D
# 21863  164750023001DC92C95BC    0.0 1970-01-01      C
# 21863  164750023001DC92C95BC    0.0 1970-01-01      D
# 23638  164920003001DC92C65C8    0.0 1970-01-01      C
# 23638  164920003001DC92C65C8    0.0 1970-01-01      D
# ...

# %%
df
# Out:
#                     itapudid  speed           eventtime sensor
# 7185   163540031001DC924C7B3    0.0 1970-01-01 00:00:00      C
# 7185   163540031001DC924C7B3    0.0 1970-01-01 00:00:00      D
# 6654   163540032001DC9248262    0.0 1970-01-01 00:00:00      E
# 6654   163540032001DC9248262    0.0 1970-01-01 00:00:00      F
# 17071  164320032001DC92C8F02    0.0 1970-01-01 00:00:00      C
# 17071  164320032001DC92C8F02    0.0 1970-01-01 00:00:00      D
# 14882  164320033001DC924D8F0    0.0 1970-01-01 00:00:00      C
# 14882  164320033001DC924D8F0    0.0 1970-01-01 00:00:00      D
# 21759  164750011001DC915CDB2    0.0 1970-01-01 00:00:00      C
# 21759  164750011001DC915CDB2    0.0 1970-01-01 00:00:00      D
# 21768  164750013001DC92C9043    0.0 1970-01-01 00:00:00      C
# 21768  164750013001DC92C9043    0.0 1970-01-01 00:00:00      D
# 21863  164750023001DC92C95BC    0.0 1970-01-01 00:00:00      C
# 21863  164750023001DC92C95BC    0.0 1970-01-01 00:00:00      D
# ...

# %%
df = df[df.eventtime != '1970-01-01']

# %%
df1 = df[df.sensor == 'C']

# %%
df2 = df[df.sensor == 'D']
df3 = df[df.sensor == 'E']
df4 = df[df.sensor == 'F']

# %%
df1.describe()
# Out:
#               speed
# count  91825.000000
# mean      56.721002
# std       89.825210
# min        0.000000
# 25%        0.000000
# 50%        6.000000
# 75%       48.000000
# max      250.000000

# %%
df2.describe()
# Out:
#               speed
# count  91825.000000
# mean      56.478748
# std       89.685440
# min        0.000000
# 25%        0.000000
# 50%        5.000000
# 75%       48.000000
# max      250.000000

# %%
df3.describe()
# Out:
#              speed
# count  1885.000000
# mean      6.198408
# std       8.774656
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       7.000000
# max      79.000000

# %%
df4.describe()
# Out:
#              speed
# count  1885.000000
# mean      6.239788
# std       8.696023
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       7.000000
# max      79.000000

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(df1.speed, bins=np.arange(df1.speed.min(), df1.speed.max()+1))
plt.show()

# %%
plt.hist(df2.speed, bins=np.arange(df2.speed.min(), df2.speed.max()+1))
plt.show()

# %%
plt.hist(df3.speed, bins=np.arange(df3.speed.min(), df3.speed.max()+1))
plt.show()

# %%
plt.hist(df4.speed, bins=np.arange(df4.speed.min(), df4.speed.max()+1))
plt.show()

# %%
import pandasql as pdsql

pysql = lambda q: pdsql.sqldf(q, globals())
str1 = """select 
             itapudid, sensor, sum(speed), stddev(speed), avg(speed), min(speed), max(speed), count(speed)
        from 
            df
        group by 
            itapudid"""

df1 = pysql(str1)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# C:\Users\600002464\AppData\Local\Continuum\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: no such function: stddev
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
df1
# Out:
#                   itapudid sensor  sum(speed)  avg(speed)  min(speed)  \
# 0    163540011001DC924C17D      C      4766.0    5.130248         0.0
# 1    163540011001DC924C17D      D      4782.0    5.147470         0.0
# 2    163540014001DC924D43A      C    277234.0  147.229952         0.0
# 3    163540014001DC924D43A      D    277414.0  147.325544         0.0
# 4    163540015001DC924C174      C     73236.0   95.235371         0.0
# 5    163540015001DC924C174      D     72678.0   94.509753         0.0
# 6    163540017001DC924DAFD      C     18102.0    6.618647         0.0
# 7    163540017001DC924DAFD      D     18235.0    6.667276         0.0
# 8    163540018001DC915C935      C    132414.0   97.939349         0.0
# 9    163540018001DC915C935      D    130248.0   96.337278         0.0
# 10   163540020001DC924C70B      C      5716.0    5.287697         0.0
# 11   163540020001DC924C70B      D      5756.0    5.324699         0.0
# ...

# %%
grouped = df.groupby('itapudid')
grouped.describe()
# Out:
#                         speed                                           \
#                         count        mean         std  min  25%    50%
# itapudid
# 163540011001DC924C17D  1858.0    5.138859    9.024653  0.0  0.0    1.0
# 163540014001DC924D43A  3766.0  147.277748  103.128388  0.0  0.0  206.0
# 163540015001DC924C174  1538.0   94.872562  107.635572  0.0  0.0    0.0
# 163540017001DC924DAFD  5470.0    6.642962   10.562976  0.0  1.0    2.0
# 163540018001DC915C935  2704.0   97.138314  107.264587  0.0  0.0    0.0
# 163540020001DC924C70B  2162.0    5.306198   10.387434  0.0  0.0    1.0
# 163540022001DC915C968  2914.0    6.562457   11.157259  0.0  1.0    1.0
# 163540023001DC924C17A  2118.0    5.368272    9.219026  0.0  0.0    1.0
# 163540024001DC915C992  2520.0    5.349603    9.879725  0.0  0.0    1.0
# 163540031001DC924C7B3   634.0    5.656151   11.079566  0.0  0.0    1.0
# 163540032001DC9248262  3734.0    6.249063    8.752886  0.0  2.0    3.0
# ...

# %%
df[df.itapudid == '163540031001DC924C7B3']
# Out:
#                     itapudid  speed           eventtime sensor
# 5966   163540031001DC924C7B3    0.0 2016-10-19 08:23:16      C
# 5966   163540031001DC924C7B3    0.0 2016-10-19 08:23:16      D
# 4785   163540031001DC924C7B3    0.0 2016-10-19 08:27:11      C
# 4785   163540031001DC924C7B3    0.0 2016-10-19 08:27:11      D
# 6123   163540031001DC924C7B3    1.0 2017-01-25 13:09:33      C
# 6123   163540031001DC924C7B3    1.0 2017-01-25 13:09:33      D
# 7186   163540031001DC924C7B3   15.0 2017-01-25 13:10:16      C
# 7186   163540031001DC924C7B3   14.0 2017-01-25 13:10:16      D
# 5967   163540031001DC924C7B3    2.0 2017-01-25 13:17:47      C
# 5967   163540031001DC924C7B3    2.0 2017-01-25 13:17:47      D
# 4786   163540031001DC924C7B3   32.0 2017-01-25 13:29:08      C
# 4786   163540031001DC924C7B3   32.0 2017-01-25 13:29:08      D
# 6124   163540031001DC924C7B3    6.0 2017-01-25 13:38:49      C
# 6124   163540031001DC924C7B3    6.0 2017-01-25 13:38:49      D
# ...
